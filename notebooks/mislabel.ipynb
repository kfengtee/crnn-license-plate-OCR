# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import numpy as np

# %%
RESULT_PATH = 'analysis/result_testset(corrected).csv'

# %%
test_result = pd.read_csv(RESULT_PATH)

# %%
for i, row in test_result.loc[test_result.editDistance != 0].iterrows():
    img = mpimg.imread(os.path.join('test_data/testset', row['path']))
    imgplot = plt.imshow(img)
    print("GT:", row['gTruth'], "\t Pred:", row['pred'])
    print("Path:", row['path'])
    plt.show()
    print('\n')
# Out:
# GT: WFU8787 	 Pred: J2787
# Path: 014048_WFU8787.jpg
# GT: XIIINAM525 	 Pred: XTVYNM525
# Path: 017887_XIIINAM525.jpg
# GT: FB5112 	 Pred: FFF85112
# Path: 017520_FB5112.jpg
# GT: WQV608 	 Pred: WV605
# Path: 018050_WQV608.jpg
# GT: PROTON72 	 Pred: PRQT0N72
# Path: 018511_PR0T0N72.jpg
# GT: WQG9336 	 Pred: WGG936
# Path: 018080_WQG9336.jpg
# GT: WUQR863 	 Pred: WU863
# Path: 000219_WUQR863.jpg
# GT: BEA1911 	 Pred: BE4191
# Path: 014438_BEA1911.jpg
# GT: WDR513 	 Pred: WQR513
# Path: 019714_WDR613.jpg
# GT: BLW310 	 Pred: BLM310
# Path: 013435_BLW310.jpg
# GT: WEC8993 	 Pred: WFC8993
# Path: 018143_WEC8993.jpg
# GT: WA7708K 	 Pred: WA770BK
# Path: 016703_WA7708K.jpg
# GT: BDW988 	 Pred: BDW1988
# Path: 019861_BDW988.jpg
# GT: JSX2327 	 Pred: JJSX2327
# Path: 016429_JSA2327.jpg
# GT: BGJ3813 	 Pred: BGJJ3813
# Path: 011222_BGJ3813.jpg
# GT: WWT3350 	 Pred: WWT335Q
# Path: 015528_WWT3350.jpg
# GT: WQM6918 	 Pred: VQM6918
# Path: 015565_WQN6918.jpg
# GT: PGD0002 	 Pred: PGD002
# ...
